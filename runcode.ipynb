# %%
from XGB_method import XGB_method

x = XGB_method(preprocess=False)
x.data_train
# Out:
#      Customer ID  Churn Category    Gender        Age  Under 30  \
# 0     0650-BWOZN               1  0.000000  37.000000  0.000000
# 1     0562-FGDCR               1  0.499474  54.000000  0.000000
# 2     6688-UZPWD               0  0.000000  23.738431  1.000000
# 3     2905-KFQUV               1  0.000000  23.000000  1.000000
# 4     9720-JJJOR               0  1.000000  41.000000  0.000000
# ...          ...             ...       ...        ...       ...
# 4221  3313-QKNKB               0  0.000000  23.000000  1.000000
# 4222  8668-KNZTI               0  0.490835  40.852346  0.265753
# 4223  8809-RIHDD               0  0.000000  60.000000  0.000000
# 4224  6663-JOCQO               0  1.000000  46.890084  0.000000
# 4225  7010-ZMVBF               0  0.492540  71.000000  0.000000
#
#       Senior Citizen   Married  Dependents  Number of Dependents        City  \
# 0           0.000000  0.031205    0.000000              0.000000  635.690933
# ...

# %%
x.data_test
# Out:
#      Customer ID    Gender        Age  Under 30  Senior Citizen   Married  \
# 0     9938-EKRGF  1.000000  73.000000  0.000000        1.000000  1.000000
# 1     7379-POKDZ  0.000000  64.000000  0.000000        0.000000  0.000000
# 2     0654-HMSHN  0.502592  16.375026  1.122527       -0.057410  1.019504
# 3     2045-BMBTJ  1.000000  35.000000  0.000000        0.000000  1.000000
# 4     0701-TJSEF  0.000000  67.000000  0.000000        1.000000  1.000000
# ...          ...       ...        ...       ...             ...       ...
# 1404  4587-VVTOX  0.000000  49.000000  0.000000        0.000000  0.000000
# 1405  7716-YTYHG  1.000000  78.000000  0.000000        1.000000  0.000000
# 1406  7649-PHJVR  0.000000  27.000000  1.000000        0.000000  1.000000
# 1407  7855-DIWPO  1.000000  38.000000  0.154146       -0.179199  1.046497
# 1408  8197-BFWVU  0.520858  39.903023  0.230461       -0.075314  0.021514
#
#       Dependents  Number of Dependents        City     Zip Code  ...  \
# ...

# %%
x.Five_Cross_Validation()
# Out:
# ===== Hyperparameters =====
# random_state = 1
# n_estimators = 1000
# lr = 0.3
# max_depth = 3
# reg_lambda = 10
# reg_alpha = 0.3
# gamma = 0.1
# min_child_weight = 1
# subsample = 1
# colsample_bytree = 1
# ...
#
# ===== Fold: 0 =====
# ===== F1-scores =====
#    F1-scores
# 0   0.999602
# 1   0.996078
# 2   0.996364
# 3   1.000000
# 4   1.000000
# 5   1.000000
# Avg = 0.999
# ...
# ===== F1-scores =====
#    F1-scores
# 0   0.942655
# 1   0.600858
# 2   0.253968
# 3   0.151515
# 4   0.193548
# 5   0.076923
# Avg = 0.370
# ...
#
# ===== Fold: 1 =====
# ===== F1-scores =====
#    F1-scores
# 0    0.99980
# 1    0.99871
# 2    1.00000
# 3    1.00000
# 4    1.00000
# 5    1.00000
# Avg = 1.000
# ...
# ===== F1-scores =====
#    F1-scores
# 0   0.948678
# 1   0.541485
# 2   0.172414
# 3   0.218182
# 4   0.125000
# 5   0.066667
# Avg = 0.345
# ...
#
# ===== Fold: 2 =====
# ===== F1-scores =====
#    F1-scores
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# Avg = 1.000
# ...

# %%
x.Prediction()
# Out:
# ===== Hyperparameters =====
# random_state = 1
# n_estimators = 1000
# lr = 0.3
# max_depth = 3
# reg_lambda = 10
# reg_alpha = 0.3
# gamma = 0.1
# min_child_weight = 1
# subsample = 1
# colsample_bytree = 1
# ...
#
# Save Prediction File as [Prediction.csv]
